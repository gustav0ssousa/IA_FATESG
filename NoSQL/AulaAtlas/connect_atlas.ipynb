# %%
# Primeira parte
import pandas as pd
import pymongo
import urllib.parse

# Definir o caminho do arquivo CSV
csv_path = r"C:\Users\Willgnner\Documents\mongo-db-atlas\IMDB top 1000.csv"

# Ler o CSV usando Pandas
df = pd.read_csv(csv_path)

# %%
# print(df.head(6))

# %%
# Segunda parte
import pymongo
import urllib.parse

# Definir usuário e senha
username = "engwillgnner_db_user"
password = "1kSNj21RL7ZwIgW4"

# Codificar a senha (caso tenha caracteres especiais)
password_encoded = urllib.parse.quote_plus(password)

# Criar a URI corretamente formatada
MONGO_URI = f"mongodb+srv://{username}:{password_encoded}@cluster0.i4a2i8b.mongodb.net/?appName=Cluster0"

# Conectar ao MongoDB Atlas
client = pymongo.MongoClient(MONGO_URI)

# Acessar o banco e a coleção
db = client["filmes"]
collection = db["filmes-series"]

print("Conexão com MongoDB Atlas estabelecida!")

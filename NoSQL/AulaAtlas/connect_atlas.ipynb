# %%
# Primeira parte
import pandas as pd
import pymongo
import urllib.parse

# Definir o caminho do arquivo CSV
csv_path = r"C:\pr0jetos\IA_FATESG\NoSQL\AulaAtlas\resultado_final.csv"

# Ler o CSV usando Pandas
df = pd.read_csv(csv_path)

# %%
# print(df.head(6))

# %%
# Segunda parte
import pymongo
import urllib.parse

# Definir usuário e senha
username = "sousadev"
password = "aNRJfOb2oFrf6opD"
# password github mongo = paMcXdQfFW08jgUi

# Codificar a senha (caso tenha caracteres especiais)
password_encoded = urllib.parse.quote_plus(password)

# Criar a URI corretamente formatada
MONGO_URI = f"mongodb+srv://sousadev:<aNRJfOb2oFrf6opD>@clusternosql.d12poai.mongodb.net/?appName=clusterNoSQL"

# Conectar ao MongoDB Atlas
client = pymongo.MongoClient(MONGO_URI)

# Acessar o banco e a coleção
db = client["music_data"]
collection = db["data"]

print("Conexão com MongoDB Atlas estabelecida!")
# Out:
# Conexão com MongoDB Atlas estabelecida!
